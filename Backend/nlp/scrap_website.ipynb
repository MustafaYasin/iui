# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = "https://www.uebungen.ws/schultern/"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="de-DE">
# <head>
# <meta charset="utf-8"/>
# <title>
#         Schultern - die besten Übungen | Uebungen.ws    </title>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.uebungen.ws/xmlrpc.php" rel="pingback"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
# <!-- This site is optimized with the Yoast SEO plugin v16.1.1 - https://yoast.com/wordpress/plugins/seo/ -->
# <link href="https://www.uebungen.ws/schultern/" rel="canonical"/>
# <link href="https://www.uebungen.ws/schultern/page/2/" rel="next"/>
# <meta content="de_DE" property="og:locale">
# <meta content="article" property="og:type"/>
# <meta content="Schultern - die besten Übungen | Uebungen.ws" property="og:title"/>
# <meta content="Die Schultermuskulatur umgibt das Schultergelenk. Im Bodybuilding wird üblicherweise zwischen drei Teilen der Schulter unterschieden: die vordere Schulter, die seitliche Schulter und die hintere Schulter. Die Schultermuskulatur bewegt und stabilisiert die Schultern nicht nur in eine, sondern in alle Richtungen. Wer seine Schulter optimal trainieren möchte, der sollte Übungen für alle drei Teile der Schulter in seinen Trainingsplan aufnehmen. Die meisten Grundübungen für den Oberkörper trainieren zumindest einen Teil der Schulter; doch gerade die seitliche Schulter kann auch durch Isolationsübungen trainiert werden." property="og:description"/>
# <meta content="https://www.uebungen.ws/schultern/" property="og:url"/>
# <meta content="Uebungen.ws" property="og:site_name"/>
# <script class="yoast-schema-graph" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://www.uebungen.ws/#website","url":"https://www.uebungen.ws/","name":"Uebungen.ws","description":"Alle \u00dcbungen f\u00fcr mehr Fitness","potentialAction":[{"@type":"SearchAction","target":"https://www.uebungen.ws/?s={search_term_string}","query-input":"required name=search_term_string"}],"inLanguage":"de-DE"},{"@type":"CollectionPage","@id":"https://www.uebungen.ws/schultern/#webpage","url":"https://www.uebungen.ws/schultern/","name":"Schultern - die besten \u00dcbungen | Uebungen.ws","isPartOf":{"@id":"https://www.uebungen.ws/#website"},"breadcrumb":{"@id":"https://www.uebungen.ws/schultern/#breadcrumb"},"inLanguage":"de-DE","potentialAction":[{"@type":"ReadAction","target":["https://www.uebungen.ws/schultern/"]}]},{"@type":"BreadcrumbList","@id":"https://www.uebungen.ws/schultern/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"WebPage","@id":"https://www.uebungen.ws/","url":"https://www.uebungen.ws/","name":"Home"}},{"@type":"ListItem","position":2,"item":{"@type":"WebPage","@id":"https://www.uebungen.ws/schultern/","url":"https://www.uebungen.ws/schultern/","name":"Schultern"}}]}]}</script>
# <!-- / Yoast SEO plugin. -->
# <link href="//maxcdn.bootstrapcdn.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://www.uebungen.ws/feed/" rel="alternate" title="Uebungen.ws » Feed" type="application/rss+xml"/>
# <link href="https://www.uebungen.ws/comments/feed/" rel="alternate" title="Uebungen.ws » Kommentar-Feed" type="application/rss+xml"/>
# <link href="https://www.uebungen.ws/schultern/feed/" rel="alternate" title="Uebungen.ws » Schultern Kategorie-Feed" type="application/rss+xml"/>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.1.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.1.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.uebungen.ws\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.8.2"}};
# 			!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])?!1:!s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([10084,65039,8205,55357,56613],[10084,65039,8203,55357,56613])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(n=t.source||{}).concatemoji?c(n.concatemoji):n.wpemoji&&n.twemoji&&(c(n.twemoji),c(n.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <!-- uebungen.ws is managing ads with Advanced Ads – https://wpadvancedads.com/ --><script>
# 						advanced_ads_ready=function(){var fns=[],listener,doc=typeof document==="object"&&document,hack=doc&&doc.documentElement.doScroll,domContentLoaded="DOMContentLoaded",loaded=doc&&(hack?/^loaded|^c/:/^loaded|^i|^c/).test(doc.readyState);if(!loaded&&doc){listener=function(){doc.removeEventListener(domContentLoaded,listener);window.removeEventListener("load",listener);loaded=1;while(listener=fns.shift())listener()};doc.addEventListener(domContentLoaded,listener);window.addEventListener("load",listener)}return function(fn){loaded?setTimeout(fn,0):fns.push(fn)}}();
# 						</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://www.uebungen.ws/wp-content/plugins/gd-star-rating/css/gdsr.css.php?t=1618002806&amp;s=a10i10m20k20c00r05%23121620243046%23121620243240%23s1pchristmas%23s1pcrystal%23s1pdarkness%23s1poxygen%23s1goxygen_gif%23s1pplain%23s1ppumpkin%23s1psoft%23s1pstarrating%23s1pstarscape%23t1pclassical%23t1pstarrating%23t1gstarrating_gif%23lsgflower%23lsg&amp;o=off&amp;ver=1.9.22" id="gdsr_style_main-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.uebungen.ws/wp-content/gd-star-rating/css/rating.css?ver=1.9.22" id="gdsr_style_xtra-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.uebungen.ws/wp-includes/css/dist/block-library/style.min.css?ver=5.8.2" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.uebungen.ws/wp-content/themes/mh_newsdesk/style.css?ver=1.0.2" id="mh-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.3.0/css/font-awesome.min.css" id="mh-font-awesome-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//fonts.googleapis.com/css?family=PT+Serif:300,400,400italic,600,700|Oswald:300,400,400italic,600,700" id="mh-google-fonts-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.uebungen.ws/wp-content/tablepress-combined.min.css?ver=5" id="tablepress-default-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.uebungen.ws/wp-content/plugins/tablepress-responsive-tables/css/tablepress-responsive.min.css?ver=1.8" id="tablepress-responsive-tables-css" media="all" rel="stylesheet" type="text/css"/>
# <script id="jquery-core-js" src="https://www.uebungen.ws/wp-includes/js/jquery/jquery.min.js?ver=3.6.0" type="text/javascript"></script>
# <script id="jquery-migrate-js" src="https://www.uebungen.ws/wp-includes/js/jquery/jquery-migrate.min.js?ver=3.3.2" type="text/javascript"></script>
# <script id="gdsr_script-js" src="https://www.uebungen.ws/wp-content/plugins/gd-star-rating/js/gdsr.js?ver=1.9.22" type="text/javascript"></script>
# <script id="mh-scripts-js" src="https://www.uebungen.ws/wp-content/themes/mh_newsdesk/js/scripts.js?ver=5.8.2" type="text/javascript"></script>
# <link href="https://www.uebungen.ws/wp-json/" rel="https://api.w.org/"/><link href="https://www.uebungen.ws/wp-json/wp/v2/categories/19" rel="alternate" type="application/json"/><link href="https://www.uebungen.ws/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://www.uebungen.ws/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 5.8.2" name="generator"/>
# <script type="text/javascript">
# //<![CDATA[
# var gdsr_cnst_nonce = "0888ea5d7b";
# var gdsr_cnst_ajax = "https://www.uebungen.ws/wp-content/plugins/gd-star-rating/ajax.php";
# var gdsr_cnst_button = 1;
# var gdsr_cnst_cache = 0;
# // ]]>
# </script>
# <!--[if IE]><style type="text/css">.ratemulti .starsbar .gdcurrent { -ms-filter:"progid:DXImageTransform.Microsoft.Alpha(Opacity=70)"; filter: alpha(opacity=70); }</style><![endif]-->
# <!--[if lt IE 9]>
# <script src="http://css3-mediaqueries-js.googlecode.com/svn/trunk/css3-mediaqueries.js"></script>
# <![endif]-->
# <!-- ANALYTICS -->
# <script>
#         (function(i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r;
#             i[r] = i[r] || function() {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date();
#             a = s.createElement(o), m = s.getElementsByTagName(o)[0];
#             a.async = 1;
#             a.src = g;
#             m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#         ga('create', 'UA-2605382-14', 'auto');
#         ga('send', 'pageview');
#     </script>
# <!-- ENDE ANALYTICS -->
# <!-- Begin Cookie Consent plugin by Silktide - http://silktide.com/cookieconsent -->
# <link href="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.css" rel="stylesheet" type="text/css"/>
# <script src="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.js"></script>
# <script>
#         window.addEventListener("load", function(){
#             window.cookieconsent.initialise({
#                 "palette": {
#                     "popup": {
#                         "background": "#000"
#                     },
#                     "button": {
#                         "background": "#f1d600"
#                     }
#                 },
#                 "content": {
#                     "message": "Diese Website benutzt Cookies. Wenn Sie die Website weiter nutzen, stimmen Sie der Verwendung von Cookies zu.",
#                     "dismiss": "Okay",
#                     "link": "Mehr Infos",
#                     "href": "https://www.uebungen.ws/impressum/"
#                 }
#             })});
#     </script>
# <!-- End Cookie Consent plugin -->
# </meta></meta></head>
# <body class="archive category category-schultern category-19 mh-right-sb aa-prefix-uebun-">
# <div id="mh-wrapper">
# <header class="mh-header">
# <div class="header-wrap clearfix">
# <div class="mh-col mh-1-3 header-logo-full">
# <a href="https://www.uebungen.ws/" rel="home" title="Uebungen.ws">
# <div class="logo-wrap" role="banner">
# <img alt="Uebungen.ws" height="92" src="https://www.uebungen.ws/wp-content/uploads/2015/03/uebungen-logo.jpg" width="380"/>
# </div>
# </a>
# </div>
# </div>
# <div class="header-menu clearfix">
# <nav class="main-nav clearfix">
# <div class="menu-top-navigation-container"><ul class="menu" id="menu-top-navigation"><li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-4893" id="menu-item-4893"><a href="https://www.uebungen.ws/arme/">Arme</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-4895" id="menu-item-4895"><a href="https://www.uebungen.ws/bauch/">Bauch</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-4897" id="menu-item-4897"><a href="https://www.uebungen.ws/brust/">Brust</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-4894" id="menu-item-4894"><a href="https://www.uebungen.ws/ruecken/">Rücken</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category current-menu-item menu-item-4898" id="menu-item-4898"><a aria-current="page" href="https://www.uebungen.ws/schultern/">Schultern</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-4892" id="menu-item-4892"><a href="https://www.uebungen.ws/beine/">Beine</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-4896" id="menu-item-4896"><a href="https://www.uebungen.ws/po/">Po</a></li>
# </ul></div> </nav>
# <div class="header-sub clearfix">
# <aside class="mh-col mh-1-3 header-search">
# <form action="https://www.uebungen.ws/" class="search-form" method="get" role="search">
# <label>
# <span class="screen-reader-text">Suche nach:</span>
# <input class="search-field" name="s" placeholder="Suche …" type="search" value=""/>
# </label>
# <input class="search-submit" type="submit" value="Suche"/>
# </form> </aside>
# </div>
# </div>
# </header><div class="mh-section mh-group">
# <div class="mh-loop" id="main-content">
# <nav class="breadcrumb"><span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a class="bc-home" href="https://www.uebungen.ws" itemprop="url"><span itemprop="title">Home</span></a></span> <span class="bc-text">Schultern</span></nav>
# <h1 class="page-title">Schultern</h1>
# <script type="text/javascript">
# var bildliste = new Array();
# bildliste[0] = "https://www.uebungen.ws/wp-content/themes/mh_newsdesk/images/koerperbilder/kategorien/neutral.jpg";
# bildliste[1] = "https://www.uebungen.ws/wp-content/themes/mh_newsdesk/images/koerperbilder/kategorien/hintereschulter.jpg";
# bildliste[2] = "https://www.uebungen.ws/wp-content/themes/mh_newsdesk/images/koerperbilder/kategorien/seitlicheschulter.jpg";
# bildliste[3] = "https://www.uebungen.ws/wp-content/themes/mh_newsdesk/images/koerperbilder/kategorien/vordereschulter.jpg";
# var bilder = new Array()
# function vorladen()
# {
# for (i = 0; i < bildliste.length; i++) {
# bilder[i] = new Image();
# bilder[i].src = bildliste[i];
# }
# }
# if (document.documentElement.clientWidth > 590) {vorladen();
# }
# function neutral() {
# if (document.documentElement.clientWidth > 590) {var bild = "url('" + bildliste[0] + "')";
# document.getElementById('katauswahlbox').style.backgroundImage=bild;
# }
# }
# function hintereschulter() {
# if (document.documentElement.clientWidth > 590) {var bild = "url('" + bildliste[1] + "')";
# document.getElementById('katauswahlbox').style.backgroundImage=bild;
# }
# }
# function seitlicheschulter() {
# if (document.documentElement.clientWidth > 590) {var bild = "url('" + bildliste[2] + "')";
# document.getElementById('katauswahlbox').style.backgroundImage=bild;
# }
# }
# function vordereschulter() {
# if (document.documentElement.clientWidth > 590) {var bild = "url('" + bildliste[3] + "')";
# document.getElementById('katauswahlbox').style.backgroundImage=bild;
# }
# }
# </script>
# <div id="katauswahlbox"><a class="katauswahlboxlink" href="https://www.uebungen.ws/schultern/hintere-schulter/" onmouseout="neutral()" onmouseover="hintereschulter()" title="Hintere Schulter">Hintere Schulter</a><a class="katauswahlboxlink" href="https://www.uebungen.ws/schultern/seitliche-schulter/" onmouseout="neutral()" onmouseover="seitlicheschulter()" title="Seitliche Schulter">Seitliche Schulter</a><a class="katauswahlboxlink" href="https://www.uebungen.ws/schultern/vordere-schulter/" onmouseout="neutral()" onmouseover="vordereschulter()" title="Vordere Schulter">Vordere Schulter</a></div><div id="kategorienbeschreibung"><p>Die Schultermuskulatur umgibt das Schultergelenk. Im Bodybuilding wird üblicherweise zwischen drei Teilen der Schulter unterschieden: die <a href="https://www.uebungen.ws/schultern/vordere-schulter/">vordere Schulter</a>, die <a href="https://www.uebungen.ws/schultern/seitliche-schulter/">seitliche Schulter</a> und die <a href="https://www.uebungen.ws/schultern/hintere-schulter/">hintere Schulter</a>. Die Schultermuskulatur bewegt und stabilisiert die Schultern nicht nur in eine, sondern in alle Richtungen. Wer seine Schulter optimal trainieren möchte, der sollte Übungen für alle drei Teile der Schulter in seinen Trainingsplan aufnehmen. Die meisten Grundübungen für den Oberkörper trainieren zumindest einen Teil der Schulter; doch gerade die seitliche Schulter kann auch durch Isolationsübungen trainiert werden.</p>
# </div><div class="unterkategorie"><h2 class="widget-title"><span><a href="https://www.uebungen.ws/schultern/hintere-schulter/" title="Hintere Schulter">Hintere Schulter</a></span></h2>
# <article class="content-list clearfix uebung post-301 post type-post status-publish format-standard has-post-thumbnail hentry category-hintere-schulter category-oberer-ruecken category-ruecken category-schultern category-trapezmuskel-nacken tag-reverse-flys">
# <div class="content-thumb content-list-thumb">
# <a href="https://www.uebungen.ws/reverse-flys/" title="Reverse Flys"><img alt="" class="attachment-uebung-thumbnail size-uebung-thumbnail wp-post-image" height="125" loading="lazy" sizes="(max-width: 250px) 100vw, 250px" src="https://www.uebungen.ws/wp-content/uploads/2011/06/reverse-flys-3-250x125.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2011/06/reverse-flys-3-250x125.jpg 250w, https://www.uebungen.ws/wp-content/uploads/2011/06/reverse-flys-3-100x50.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2011/06/reverse-flys-3-300x150.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2011/06/reverse-flys-3-768x384.jpg 768w, https://www.uebungen.ws/wp-content/uploads/2011/06/reverse-flys-3.jpg 777w" width="250"/></a>
# </div>
# <header class="content-list-header">
# <h3 class="content-list-title"><a href="https://www.uebungen.ws/reverse-flys/" rel="bookmark" title="Reverse Flys">Reverse Flys</a></h3>
# </header>
# <div class="content-list-excerpt">
# <p>Benötigtes Equipment: Kurzhanteln<br/>Schwierigkeitsgrad: mittel</p>
# <div style="display: none">VN:F [1.9.22_1171]</div><div class="thumblock"><div class="gdt-size-24 gdthumb gdup" id="gdsr_thumb_301_a_up"><a class="gdt-starrating" id="gdsrX301XupXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loadup" id="gdsr_thumb_301_a_loader_up" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="gdt-size-24 gdthumb gddw" id="gdsr_thumb_301_a_dw"><a class="gdt-starrating" id="gdsrX301XdwXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loaddw" id="gdsr_thumb_301_a_loader_dw" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="ratingtext"><div class="gdt-size-24 gdthumbtext" id="gdsr_thumb_text_301_a">Rating: <strong>+264</strong> (from 710 votes)</div></div><div class="raterclear"></div></div> </div>
# </article>
# <article class="content-list clearfix uebung post-682 post type-post status-publish format-standard has-post-thumbnail hentry category-hintere-schulter category-oberer-ruecken category-ruecken category-schultern category-trapezmuskel-nacken tag-butterfly-reverse tag-reverse-flys">
# <div class="content-thumb content-list-thumb">
# <a href="https://www.uebungen.ws/butterfly-reverse/" title="Butterfly Reverse"><img alt="" class="attachment-uebung-thumbnail size-uebung-thumbnail wp-post-image" height="125" loading="lazy" sizes="(max-width: 250px) 100vw, 250px" src="https://www.uebungen.ws/wp-content/uploads/2011/07/butterfly-reverse-250x125.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2011/07/butterfly-reverse-250x125.jpg 250w, https://www.uebungen.ws/wp-content/uploads/2011/07/butterfly-reverse-100x50.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2011/07/butterfly-reverse-300x150.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2011/07/butterfly-reverse-768x384.jpg 768w, https://www.uebungen.ws/wp-content/uploads/2011/07/butterfly-reverse.jpg 777w" width="250"/></a>
# </div>
# <header class="content-list-header">
# <h3 class="content-list-title"><a href="https://www.uebungen.ws/butterfly-reverse/" rel="bookmark" title="Butterfly Reverse">Butterfly Reverse</a></h3>
# </header>
# <div class="content-list-excerpt">
# <p>Benötigtes Equipment: Verstellbares Butterfly-Gerät<br/>Schwierigkeitsgrad: niedrig</p>
# <div style="display: none">VN:F [1.9.22_1171]</div><div class="thumblock"><div class="gdt-size-24 gdthumb gdup" id="gdsr_thumb_682_a_up"><a class="gdt-starrating" id="gdsrX682XupXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loadup" id="gdsr_thumb_682_a_loader_up" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="gdt-size-24 gdthumb gddw" id="gdsr_thumb_682_a_dw"><a class="gdt-starrating" id="gdsrX682XdwXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loaddw" id="gdsr_thumb_682_a_loader_dw" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="ratingtext"><div class="gdt-size-24 gdthumbtext" id="gdsr_thumb_text_682_a">Rating: <strong>+209</strong> (from 435 votes)</div></div><div class="raterclear"></div></div> </div>
# </article>
# <article class="content-list clearfix uebung post-1172 post type-post status-publish format-standard has-post-thumbnail hentry category-hintere-schulter category-latissimus category-oberer-ruecken category-ruecken category-schultern category-trapezmuskel-nacken tag-rudern">
# <div class="content-thumb content-list-thumb">
# <a href="https://www.uebungen.ws/rudern-in-rueckenlage/" title="Rudern in Rückenlage"><img alt="" class="attachment-uebung-thumbnail size-uebung-thumbnail wp-post-image" height="125" loading="lazy" sizes="(max-width: 250px) 100vw, 250px" src="https://www.uebungen.ws/wp-content/uploads/2011/08/rudern-in-rueckenlage-250x125.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2011/08/rudern-in-rueckenlage-250x125.jpg 250w, https://www.uebungen.ws/wp-content/uploads/2011/08/rudern-in-rueckenlage-100x50.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2011/08/rudern-in-rueckenlage-300x150.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2011/08/rudern-in-rueckenlage-768x384.jpg 768w, https://www.uebungen.ws/wp-content/uploads/2011/08/rudern-in-rueckenlage.jpg 777w" width="250"/></a>
# </div>
# <header class="content-list-header">
# <h3 class="content-list-title"><a href="https://www.uebungen.ws/rudern-in-rueckenlage/" rel="bookmark" title="Rudern in Rückenlage">Rudern in Rückenlage</a></h3>
# </header>
# <div class="content-list-excerpt">
# <p>Benötigtes Equipment: Langhantel<br/>Schwierigkeitsgrad: niedrig</p>
# <div style="display: none">VN:F [1.9.22_1171]</div><div class="thumblock"><div class="gdt-size-24 gdthumb gdup" id="gdsr_thumb_1172_a_up"><a class="gdt-starrating" id="gdsrX1172XupXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loadup" id="gdsr_thumb_1172_a_loader_up" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="gdt-size-24 gdthumb gddw" id="gdsr_thumb_1172_a_dw"><a class="gdt-starrating" id="gdsrX1172XdwXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loaddw" id="gdsr_thumb_1172_a_loader_dw" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="ratingtext"><div class="gdt-size-24 gdthumbtext" id="gdsr_thumb_text_1172_a">Rating: <strong>+37</strong> (from 307 votes)</div></div><div class="raterclear"></div></div> </div>
# </article>
# <article class="content-list clearfix uebung post-545 post type-post status-publish format-standard has-post-thumbnail hentry category-hintere-schulter category-ruecken category-schultern category-trapezmuskel-nacken tag-reverse-flys">
# <div class="content-thumb content-list-thumb">
# <a href="https://www.uebungen.ws/reverse-flys-am-kabelzug/" title="Reverse Flys am Kabelzug"><img alt="" class="attachment-uebung-thumbnail size-uebung-thumbnail wp-post-image" height="125" loading="lazy" sizes="(max-width: 250px) 100vw, 250px" src="https://www.uebungen.ws/wp-content/uploads/2011/07/reverse-flys-am-kabelzug-1-250x125.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2011/07/reverse-flys-am-kabelzug-1-250x125.jpg 250w, https://www.uebungen.ws/wp-content/uploads/2011/07/reverse-flys-am-kabelzug-1-100x50.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2011/07/reverse-flys-am-kabelzug-1-300x150.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2011/07/reverse-flys-am-kabelzug-1-768x384.jpg 768w, https://www.uebungen.ws/wp-content/uploads/2011/07/reverse-flys-am-kabelzug-1.jpg 777w" width="250"/></a>
# </div>
# <header class="content-list-header">
# <h3 class="content-list-title"><a href="https://www.uebungen.ws/reverse-flys-am-kabelzug/" rel="bookmark" title="Reverse Flys am Kabelzug">Reverse Flys am Kabelzug</a></h3>
# </header>
# <div class="content-list-excerpt">
# <p>Benötigtes Equipment: Kabelzug<br/>Schwierigkeitsgrad: mittel</p>
# <div style="display: none">VN:F [1.9.22_1171]</div><div class="thumblock"><div class="gdt-size-24 gdthumb gdup" id="gdsr_thumb_545_a_up"><a class="gdt-starrating" id="gdsrX545XupXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loadup" id="gdsr_thumb_545_a_loader_up" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="gdt-size-24 gdthumb gddw" id="gdsr_thumb_545_a_dw"><a class="gdt-starrating" id="gdsrX545XdwXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loaddw" id="gdsr_thumb_545_a_loader_dw" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="ratingtext"><div class="gdt-size-24 gdthumbtext" id="gdsr_thumb_text_545_a">Rating: <strong>+37</strong> (from 189 votes)</div></div><div class="raterclear"></div></div> </div>
# </article>
# <article class="content-list clearfix uebung post-542 post type-post status-publish format-standard has-post-thumbnail hentry category-hintere-schulter category-ruecken category-schultern category-trapezmuskel-nacken tag-reverse-flys">
# <div class="content-thumb content-list-thumb">
# <a href="https://www.uebungen.ws/vorgebeugte-reverse-flys-am-kabelzug/" title="Vorgebeugte Reverse Flys am Kabelzug"><img alt="" class="attachment-uebung-thumbnail size-uebung-thumbnail wp-post-image" height="125" loading="lazy" sizes="(max-width: 250px) 100vw, 250px" src="https://www.uebungen.ws/wp-content/uploads/2011/07/vorgebeugte-reverse-flys-am-kabelzug-250x125.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2011/07/vorgebeugte-reverse-flys-am-kabelzug-250x125.jpg 250w, https://www.uebungen.ws/wp-content/uploads/2011/07/vorgebeugte-reverse-flys-am-kabelzug-100x50.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2011/07/vorgebeugte-reverse-flys-am-kabelzug-300x150.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2011/07/vorgebeugte-reverse-flys-am-kabelzug-768x384.jpg 768w, https://www.uebungen.ws/wp-content/uploads/2011/07/vorgebeugte-reverse-flys-am-kabelzug.jpg 777w" width="250"/></a>
# </div>
# <header class="content-list-header">
# <h3 class="content-list-title"><a href="https://www.uebungen.ws/vorgebeugte-reverse-flys-am-kabelzug/" rel="bookmark" title="Vorgebeugte Reverse Flys am Kabelzug">Vorgebeugte Reverse Flys am Kabelzug</a></h3>
# </header>
# <div class="content-list-excerpt">
# <p>Benötigtes Equipment: Kabelzug<br/>Schwierigkeitsgrad: mittel</p>
# <div style="display: none">VN:F [1.9.22_1171]</div><div class="thumblock"><div class="gdt-size-24 gdthumb gdup" id="gdsr_thumb_542_a_up"><a class="gdt-starrating" id="gdsrX542XupXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loadup" id="gdsr_thumb_542_a_loader_up" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="gdt-size-24 gdthumb gddw" id="gdsr_thumb_542_a_dw"><a class="gdt-starrating" id="gdsrX542XdwXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loaddw" id="gdsr_thumb_542_a_loader_dw" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="ratingtext"><div class="gdt-size-24 gdthumbtext" id="gdsr_thumb_text_542_a">Rating: <strong>+17</strong> (from 209 votes)</div></div><div class="raterclear"></div></div> </div>
# </article><a class="button" href="https://www.uebungen.ws/schultern/hintere-schulter/" title="Hintere Schulter"><span>Alle Übungen anzeigen</span></a></div><div class="unterkategorie"><h2 class="widget-title"><span><a href="https://www.uebungen.ws/schultern/seitliche-schulter/" title="Seitliche Schulter">Seitliche Schulter</a></span></h2>
# <article class="content-list clearfix uebung post-221 post type-post status-publish format-standard has-post-thumbnail hentry category-schultern category-seitliche-schulter category-vordere-schulter tag-schulterdruecken">
# <div class="content-thumb content-list-thumb">
# <a href="https://www.uebungen.ws/kurzhantel-schulterdruecken/" title="Kurzhantel-Schulterdrücken"><img alt="" class="attachment-uebung-thumbnail size-uebung-thumbnail wp-post-image" height="125" loading="lazy" sizes="(max-width: 250px) 100vw, 250px" src="https://www.uebungen.ws/wp-content/uploads/2011/06/kurzhantel-schulterdruecken-250x125.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2011/06/kurzhantel-schulterdruecken-250x125.jpg 250w, https://www.uebungen.ws/wp-content/uploads/2011/06/kurzhantel-schulterdruecken-100x50.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2011/06/kurzhantel-schulterdruecken-300x150.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2011/06/kurzhantel-schulterdruecken-768x384.jpg 768w, https://www.uebungen.ws/wp-content/uploads/2011/06/kurzhantel-schulterdruecken.jpg 777w" width="250"/></a>
# </div>
# <header class="content-list-header">
# <h3 class="content-list-title"><a href="https://www.uebungen.ws/kurzhantel-schulterdruecken/" rel="bookmark" title="Kurzhantel-Schulterdrücken">Kurzhantel-Schulterdrücken</a></h3>
# </header>
# <div class="content-list-excerpt">
# <p>Benötigtes Equipment: Kurzhanteln<br/>Schwierigkeitsgrad: mittel</p>
# <div style="display: none">VN:F [1.9.22_1171]</div><div class="thumblock"><div class="gdt-size-24 gdthumb gdup" id="gdsr_thumb_221_a_up"><a class="gdt-starrating" id="gdsrX221XupXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loadup" id="gdsr_thumb_221_a_loader_up" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="gdt-size-24 gdthumb gddw" id="gdsr_thumb_221_a_dw"><a class="gdt-starrating" id="gdsrX221XdwXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loaddw" id="gdsr_thumb_221_a_loader_dw" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="ratingtext"><div class="gdt-size-24 gdthumbtext" id="gdsr_thumb_text_221_a">Rating: <strong>+358</strong> (from 784 votes)</div></div><div class="raterclear"></div></div> </div>
# </article>
# <article class="content-list clearfix uebung post-128 post type-post status-publish format-standard has-post-thumbnail hentry category-schultern category-seitliche-schulter tag-seitheben">
# <div class="content-thumb content-list-thumb">
# <a href="https://www.uebungen.ws/seitheben/" title="Seitheben"><img alt="" class="attachment-uebung-thumbnail size-uebung-thumbnail wp-post-image" height="125" loading="lazy" sizes="(max-width: 250px) 100vw, 250px" src="https://www.uebungen.ws/wp-content/uploads/2011/06/seitheben-250x125.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2011/06/seitheben-250x125.jpg 250w, https://www.uebungen.ws/wp-content/uploads/2011/06/seitheben-100x50.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2011/06/seitheben-300x150.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2011/06/seitheben-768x384.jpg 768w, https://www.uebungen.ws/wp-content/uploads/2011/06/seitheben.jpg 777w" width="250"/></a>
# </div>
# <header class="content-list-header">
# <h3 class="content-list-title"><a href="https://www.uebungen.ws/seitheben/" rel="bookmark" title="Seitheben">Seitheben</a></h3>
# </header>
# <div class="content-list-excerpt">
# <p>Benötigtes Equipment: Kurzhanteln<br/>Schwierigkeitsgrad: mittel</p>
# <div style="display: none">VN:F [1.9.22_1171]</div><div class="thumblock"><div class="gdt-size-24 gdthumb gdup" id="gdsr_thumb_128_a_up"><a class="gdt-starrating" id="gdsrX128XupXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loadup" id="gdsr_thumb_128_a_loader_up" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="gdt-size-24 gdthumb gddw" id="gdsr_thumb_128_a_dw"><a class="gdt-starrating" id="gdsrX128XdwXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loaddw" id="gdsr_thumb_128_a_loader_dw" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="ratingtext"><div class="gdt-size-24 gdthumbtext" id="gdsr_thumb_text_128_a">Rating: <strong>+246</strong> (from 400 votes)</div></div><div class="raterclear"></div></div> </div>
# </article>
# <article class="content-list clearfix uebung post-1140 post type-post status-publish format-standard has-post-thumbnail hentry category-schultern category-seitliche-schulter category-vordere-schulter tag-schulterdruecken">
# <div class="content-thumb content-list-thumb">
# <a href="https://www.uebungen.ws/schulterdruecken/" title="Schulterdrücken"><img alt="" class="attachment-uebung-thumbnail size-uebung-thumbnail wp-post-image" height="125" loading="lazy" sizes="(max-width: 250px) 100vw, 250px" src="https://www.uebungen.ws/wp-content/uploads/2011/08/schulterdruecken-250x125.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2011/08/schulterdruecken-250x125.jpg 250w, https://www.uebungen.ws/wp-content/uploads/2011/08/schulterdruecken-100x50.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2011/08/schulterdruecken-300x150.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2011/08/schulterdruecken-768x384.jpg 768w, https://www.uebungen.ws/wp-content/uploads/2011/08/schulterdruecken.jpg 777w" width="250"/></a>
# </div>
# <header class="content-list-header">
# <h3 class="content-list-title"><a href="https://www.uebungen.ws/schulterdruecken/" rel="bookmark" title="Schulterdrücken">Schulterdrücken</a></h3>
# </header>
# <div class="content-list-excerpt">
# <p>Benötigtes Equipment: Langhantel<br/>Schwierigkeitsgrad: mittel</p>
# <div style="display: none">VN:F [1.9.22_1171]</div><div class="thumblock"><div class="gdt-size-24 gdthumb gdup" id="gdsr_thumb_1140_a_up"><a class="gdt-starrating" id="gdsrX1140XupXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loadup" id="gdsr_thumb_1140_a_loader_up" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="gdt-size-24 gdthumb gddw" id="gdsr_thumb_1140_a_dw"><a class="gdt-starrating" id="gdsrX1140XdwXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loaddw" id="gdsr_thumb_1140_a_loader_dw" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="ratingtext"><div class="gdt-size-24 gdthumbtext" id="gdsr_thumb_text_1140_a">Rating: <strong>+106</strong> (from 414 votes)</div></div><div class="raterclear"></div></div> </div>
# </article>
# <article class="content-list clearfix uebung post-327 post type-post status-publish format-standard has-post-thumbnail hentry category-oberer-ruecken category-ruecken category-schultern category-seitliche-schulter category-trapezmuskel-nacken tag-aufrechtes-rudern">
# <div class="content-thumb content-list-thumb">
# <a href="https://www.uebungen.ws/aufrechtes-rudern/" title="Aufrechtes Rudern"><img alt="" class="attachment-uebung-thumbnail size-uebung-thumbnail wp-post-image" height="125" loading="lazy" sizes="(max-width: 250px) 100vw, 250px" src="https://www.uebungen.ws/wp-content/uploads/2011/06/aufrechtes-rudern-250x125.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2011/06/aufrechtes-rudern-250x125.jpg 250w, https://www.uebungen.ws/wp-content/uploads/2011/06/aufrechtes-rudern-100x50.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2011/06/aufrechtes-rudern-300x150.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2011/06/aufrechtes-rudern-768x384.jpg 768w, https://www.uebungen.ws/wp-content/uploads/2011/06/aufrechtes-rudern.jpg 777w" width="250"/></a>
# </div>
# <header class="content-list-header">
# <h3 class="content-list-title"><a href="https://www.uebungen.ws/aufrechtes-rudern/" rel="bookmark" title="Aufrechtes Rudern">Aufrechtes Rudern</a></h3>
# </header>
# <div class="content-list-excerpt">
# <p>Benötigtes Equipment: Langhantel oder SZ-Stange<br/>Schwierigkeitsgrad: mittel</p>
# <div style="display: none">VN:F [1.9.22_1171]</div><div class="thumblock"><div class="gdt-size-24 gdthumb gdup" id="gdsr_thumb_327_a_up"><a class="gdt-starrating" id="gdsrX327XupXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loadup" id="gdsr_thumb_327_a_loader_up" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="gdt-size-24 gdthumb gddw" id="gdsr_thumb_327_a_dw"><a class="gdt-starrating" id="gdsrX327XdwXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loaddw" id="gdsr_thumb_327_a_loader_dw" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="ratingtext"><div class="gdt-size-24 gdthumbtext" id="gdsr_thumb_text_327_a">Rating: <strong>+58</strong> (from 538 votes)</div></div><div class="raterclear"></div></div> </div>
# </article>
# <article class="content-list clearfix uebung post-1237 post type-post status-publish format-standard has-post-thumbnail hentry category-schultern category-seitliche-schulter tag-seitheben">
# <div class="content-thumb content-list-thumb">
# <a href="https://www.uebungen.ws/seitheben-am-kabelzug/" title="Seitheben am Kabelzug"><img alt="" class="attachment-uebung-thumbnail size-uebung-thumbnail wp-post-image" height="125" loading="lazy" sizes="(max-width: 250px) 100vw, 250px" src="https://www.uebungen.ws/wp-content/uploads/2011/08/seitheben-am-kabelzug-250x125.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2011/08/seitheben-am-kabelzug-250x125.jpg 250w, https://www.uebungen.ws/wp-content/uploads/2011/08/seitheben-am-kabelzug-100x50.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2011/08/seitheben-am-kabelzug-300x150.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2011/08/seitheben-am-kabelzug-768x384.jpg 768w, https://www.uebungen.ws/wp-content/uploads/2011/08/seitheben-am-kabelzug.jpg 777w" width="250"/></a>
# </div>
# <header class="content-list-header">
# <h3 class="content-list-title"><a href="https://www.uebungen.ws/seitheben-am-kabelzug/" rel="bookmark" title="Seitheben am Kabelzug">Seitheben am Kabelzug</a></h3>
# </header>
# <div class="content-list-excerpt">
# <p>Benötigtes Equipment: Kabelzug<br/>Schwierigkeitsgrad: niedrig</p>
# <div style="display: none">VN:F [1.9.22_1171]</div><div class="thumblock"><div class="gdt-size-24 gdthumb gdup" id="gdsr_thumb_1237_a_up"><a class="gdt-starrating" id="gdsrX1237XupXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loadup" id="gdsr_thumb_1237_a_loader_up" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="gdt-size-24 gdthumb gddw" id="gdsr_thumb_1237_a_dw"><a class="gdt-starrating" id="gdsrX1237XdwXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loaddw" id="gdsr_thumb_1237_a_loader_dw" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="ratingtext"><div class="gdt-size-24 gdthumbtext" id="gdsr_thumb_text_1237_a">Rating: <strong>+47</strong> (from 123 votes)</div></div><div class="raterclear"></div></div> </div>
# </article><a class="button" href="https://www.uebungen.ws/schultern/seitliche-schulter/" title="Seitliche Schulter"><span>Alle Übungen anzeigen</span></a></div><div class="unterkategorie"><h2 class="widget-title"><span><a href="https://www.uebungen.ws/schultern/vordere-schulter/" title="Vordere Schulter">Vordere Schulter</a></span></h2>
# <article class="content-list clearfix uebung post-221 post type-post status-publish format-standard has-post-thumbnail hentry category-schultern category-seitliche-schulter category-vordere-schulter tag-schulterdruecken">
# <div class="content-thumb content-list-thumb">
# <a href="https://www.uebungen.ws/kurzhantel-schulterdruecken/" title="Kurzhantel-Schulterdrücken"><img alt="" class="attachment-uebung-thumbnail size-uebung-thumbnail wp-post-image" height="125" loading="lazy" sizes="(max-width: 250px) 100vw, 250px" src="https://www.uebungen.ws/wp-content/uploads/2011/06/kurzhantel-schulterdruecken-250x125.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2011/06/kurzhantel-schulterdruecken-250x125.jpg 250w, https://www.uebungen.ws/wp-content/uploads/2011/06/kurzhantel-schulterdruecken-100x50.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2011/06/kurzhantel-schulterdruecken-300x150.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2011/06/kurzhantel-schulterdruecken-768x384.jpg 768w, https://www.uebungen.ws/wp-content/uploads/2011/06/kurzhantel-schulterdruecken.jpg 777w" width="250"/></a>
# </div>
# <header class="content-list-header">
# <h3 class="content-list-title"><a href="https://www.uebungen.ws/kurzhantel-schulterdruecken/" rel="bookmark" title="Kurzhantel-Schulterdrücken">Kurzhantel-Schulterdrücken</a></h3>
# </header>
# <div class="content-list-excerpt">
# <p>Benötigtes Equipment: Kurzhanteln<br/>Schwierigkeitsgrad: mittel</p>
# <div style="display: none">VN:F [1.9.22_1171]</div><div class="thumblock"><div class="gdt-size-24 gdthumb gdup" id="gdsr_thumb_221_a_up"><a class="gdt-starrating" id="gdsrX221XupXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loadup" id="gdsr_thumb_221_a_loader_up" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="gdt-size-24 gdthumb gddw" id="gdsr_thumb_221_a_dw"><a class="gdt-starrating" id="gdsrX221XdwXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loaddw" id="gdsr_thumb_221_a_loader_dw" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="ratingtext"><div class="gdt-size-24 gdthumbtext" id="gdsr_thumb_text_221_a">Rating: <strong>+358</strong> (from 784 votes)</div></div><div class="raterclear"></div></div> </div>
# </article>
# <article class="content-list clearfix uebung post-324 post type-post status-publish format-standard has-post-thumbnail hentry category-schultern category-vordere-schulter tag-frontheben">
# <div class="content-thumb content-list-thumb">
# <a href="https://www.uebungen.ws/frontheben/" title="Frontheben"><img alt="" class="attachment-uebung-thumbnail size-uebung-thumbnail wp-post-image" height="125" loading="lazy" sizes="(max-width: 250px) 100vw, 250px" src="https://www.uebungen.ws/wp-content/uploads/2011/06/frontheben-250x125.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2011/06/frontheben-250x125.jpg 250w, https://www.uebungen.ws/wp-content/uploads/2011/06/frontheben-100x50.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2011/06/frontheben-300x150.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2011/06/frontheben-768x384.jpg 768w, https://www.uebungen.ws/wp-content/uploads/2011/06/frontheben.jpg 777w" width="250"/></a>
# </div>
# <header class="content-list-header">
# <h3 class="content-list-title"><a href="https://www.uebungen.ws/frontheben/" rel="bookmark" title="Frontheben">Frontheben</a></h3>
# </header>
# <div class="content-list-excerpt">
# <p>Benötigtes Equipment: Kurzhanteln<br/>Schwierigkeitsgrad: niedrig</p>
# <div style="display: none">VN:F [1.9.22_1171]</div><div class="thumblock"><div class="gdt-size-24 gdthumb gdup" id="gdsr_thumb_324_a_up"><a class="gdt-starrating" id="gdsrX324XupXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loadup" id="gdsr_thumb_324_a_loader_up" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="gdt-size-24 gdthumb gddw" id="gdsr_thumb_324_a_dw"><a class="gdt-starrating" id="gdsrX324XdwXaX25X24XY" rel="nofollow"></a></div><div class="ratingloader loaddw" id="gdsr_thumb_324_a_loader_dw" style="display: none; width: 24px "><div class="loader flower thumb" style="width: 24px; height: 24px;"></div></div><div class="ratingtext"><div class="gdt-size-24 gdthumbtext" id="gdsr_thumb_text_324_a">Rating: <strong>+107</strong> (from 237 votes)</div></div><div class="raterclear"></div></div> </div>
# </article>
# <article class="content-list clearfix uebung post-1140 post type-post status-publish format-standard has-post-thumbnail hentry category-schultern category-seitliche-schulter category-vordere-schulter tag-schulterdruecken">
# <div class="content-thumb content-list-thumb">
# <a href="https://www.uebungen.ws/schulterdruecken/" title="Schulterdrücken"><img alt="" class="attachment-uebung-thumbnail size-uebung-thumbnail wp-post-image" height="125" loading="lazy" sizes="(max-width: 250px) 100vw, 250px" src="https://www.uebungen.ws/wp-content/uploads/2011/08/schulterdruecken-250x125.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2011/08/schulterdruecken-250x125.jpg 250w, https://www.uebungen.ws/wp-content/uploads/2011/08/schulterdruecken-100x50.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2011/08/schulterdruecken-300x150.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2011/08/schulterdruecken-768x384.jpg 768w, https://www.uebungen.ws/wp-content/uploads/2011/08/schulterdruecken.jpg 777w" width="250"/></a>
# </div>
# <header class="content-list-header">
# <h3 class="content-list-title"><a href="https://www.uebungen.ws/schulterdruecken/" rel="bookmark" title="Schulterdrücken">Schulterdrücken</a></h3>
# </header>
# <div class="content-list-excerpt">
# <p>Benötigtes Equipment: Langhantel<br/>Schwierigkeitsgrad: mittel</p>
# ...
# </div>
# <h3 class="cp-title-small"><a href="https://www.uebungen.ws/wie-viel-protein-brauche-ich-pro-tag/" rel="bookmark" title="Wie viel Protein brauche ich pro Tag?">Wie viel Protein brauche ich pro Tag?</a></h3>
# </article>
# <hr class="mh-separator"/> <article class="cp-wrap cp-small clearfix">
# <div class="cp-thumb-small">
# <a href="https://www.uebungen.ws/supplements-die-welt-der-nahrungsergaenzungsmittel/" title="Supplements: Die Welt der Nahrungsergänzungsmittel"><img alt="Supplements: Die Welt der Nahrungsergänzungsmittel" class="attachment-cp-thumb-small size-cp-thumb-small wp-post-image" height="67" loading="lazy" sizes="(max-width: 120px) 100vw, 120px" src="https://www.uebungen.ws/wp-content/uploads/2015/04/supplements-nahrungsergaenzungsmittel-120x67.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2015/04/supplements-nahrungsergaenzungsmittel-120x67.jpg 120w, https://www.uebungen.ws/wp-content/uploads/2015/04/supplements-nahrungsergaenzungsmittel-100x56.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2015/04/supplements-nahrungsergaenzungsmittel-300x169.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2015/04/supplements-nahrungsergaenzungsmittel.jpg 777w, https://www.uebungen.ws/wp-content/uploads/2015/04/supplements-nahrungsergaenzungsmittel-180x101.jpg 180w, https://www.uebungen.ws/wp-content/uploads/2015/04/supplements-nahrungsergaenzungsmittel-260x146.jpg 260w, https://www.uebungen.ws/wp-content/uploads/2015/04/supplements-nahrungsergaenzungsmittel-373x210.jpg 373w" width="120"/></a>
# </div>
# <h3 class="cp-title-small"><a href="https://www.uebungen.ws/supplements-die-welt-der-nahrungsergaenzungsmittel/" rel="bookmark" title="Supplements: Die Welt der Nahrungsergänzungsmittel">Supplements: Die Welt der Nahrungsergänzungsmittel</a></h3>
# </article>
# <hr class="mh-separator"/> </div></div><div class="sb-widget clearfix"><h4 class="widget-title"><span><a class="widget-title-link" href="https://www.uebungen.ws/rezepte/">Beliebte Rezepte</a></span></h4> <div class="mh-cp-widget clearfix"> <article class="cp-wrap cp-large clearfix">
# <div class="cp-thumb-xl">
# <a href="https://www.uebungen.ws/fruehstueck-2-0-teil-1-so-fruehstuecken-die-champions/" title="Frühstück 2.0, Teil 1: So frühstücken die Champions"><img alt="Magerquark-Traubensaft-Shake" class="attachment-cp-thumb-xl size-cp-thumb-xl wp-post-image" height="210" loading="lazy" sizes="(max-width: 373px) 100vw, 373px" src="https://www.uebungen.ws/wp-content/uploads/2015/04/magerquark-traubensaft-shake-373x210.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2015/04/magerquark-traubensaft-shake-373x210.jpg 373w, https://www.uebungen.ws/wp-content/uploads/2015/04/magerquark-traubensaft-shake-100x56.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2015/04/magerquark-traubensaft-shake-300x169.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2015/04/magerquark-traubensaft-shake.jpg 777w, https://www.uebungen.ws/wp-content/uploads/2015/04/magerquark-traubensaft-shake-180x101.jpg 180w, https://www.uebungen.ws/wp-content/uploads/2015/04/magerquark-traubensaft-shake-260x146.jpg 260w, https://www.uebungen.ws/wp-content/uploads/2015/04/magerquark-traubensaft-shake-120x67.jpg 120w" width="373"/></a>
# </div>
# <h3 class="cp-title-xl"><a href="https://www.uebungen.ws/fruehstueck-2-0-teil-1-so-fruehstuecken-die-champions/" rel="bookmark" title="Frühstück 2.0, Teil 1: So frühstücken die Champions">Frühstück 2.0, Teil 1: So frühstücken die Champions</a></h3>
# <div class="cp-excerpt-xl">
# <p>Marmeladenbrot, Nutellabrötchen oder Croissant – so frühstücken Anfänger. Denn diese Mahlzeiten bestehen fast ausschließlich aus kurzkettigen Kohlenhydraten und enthalten wenige wichtige Nährstoffe. Das Frühstück der…</p>
# <a class="button" href="https://www.uebungen.ws/fruehstueck-2-0-teil-1-so-fruehstuecken-die-champions/">
# <span>Read More</span>
# </a> </div>
# </article>
# <hr class="mh-separator"/> <article class="cp-wrap cp-small clearfix">
# <div class="cp-thumb-small">
# <a href="https://www.uebungen.ws/fruehstueck-2-0-teil-3-banana-pancakes/" title="Frühstück 2.0, Teil 3: Banana-Pancakes"><img alt="Frühstück 2.0, Teil 3: Banana-Pancakes" class="attachment-cp-thumb-small size-cp-thumb-small wp-post-image" height="67" loading="lazy" sizes="(max-width: 120px) 100vw, 120px" src="https://www.uebungen.ws/wp-content/uploads/2015/04/bananen-pfannkuchen-120x67.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2015/04/bananen-pfannkuchen-120x67.jpg 120w, https://www.uebungen.ws/wp-content/uploads/2015/04/bananen-pfannkuchen-100x56.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2015/04/bananen-pfannkuchen-300x169.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2015/04/bananen-pfannkuchen.jpg 777w, https://www.uebungen.ws/wp-content/uploads/2015/04/bananen-pfannkuchen-180x101.jpg 180w, https://www.uebungen.ws/wp-content/uploads/2015/04/bananen-pfannkuchen-260x146.jpg 260w, https://www.uebungen.ws/wp-content/uploads/2015/04/bananen-pfannkuchen-373x210.jpg 373w" width="120"/></a>
# </div>
# <h3 class="cp-title-small"><a href="https://www.uebungen.ws/fruehstueck-2-0-teil-3-banana-pancakes/" rel="bookmark" title="Frühstück 2.0, Teil 3: Banana-Pancakes">Frühstück 2.0, Teil 3: Banana-Pancakes</a></h3>
# </article>
# <hr class="mh-separator"/> <article class="cp-wrap cp-small clearfix">
# <div class="cp-thumb-small">
# <a href="https://www.uebungen.ws/bodybuilder-esst-mehr-linsen-teil-1-tuerkische-linsensuppe/" title="Bodybuilder, esst mehr Linsen! Teil 1: Türkische Linsensuppe"><img alt="Bodybuilder, esst mehr Linsen!" class="attachment-cp-thumb-small size-cp-thumb-small wp-post-image" height="67" loading="lazy" sizes="(max-width: 120px) 100vw, 120px" src="https://www.uebungen.ws/wp-content/uploads/2015/04/linsen3-120x67.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2015/04/linsen3-120x67.jpg 120w, https://www.uebungen.ws/wp-content/uploads/2015/04/linsen3-100x56.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2015/04/linsen3-300x169.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2015/04/linsen3.jpg 777w, https://www.uebungen.ws/wp-content/uploads/2015/04/linsen3-180x101.jpg 180w, https://www.uebungen.ws/wp-content/uploads/2015/04/linsen3-260x146.jpg 260w, https://www.uebungen.ws/wp-content/uploads/2015/04/linsen3-373x210.jpg 373w" width="120"/></a>
# </div>
# <h3 class="cp-title-small"><a href="https://www.uebungen.ws/bodybuilder-esst-mehr-linsen-teil-1-tuerkische-linsensuppe/" rel="bookmark" title="Bodybuilder, esst mehr Linsen! Teil 1: Türkische Linsensuppe">Bodybuilder, esst mehr Linsen! Teil 1: Türkische Linsensuppe</a></h3>
# </article>
# <hr class="mh-separator"/> <article class="cp-wrap cp-small clearfix">
# <div class="cp-thumb-small">
# <a href="https://www.uebungen.ws/fitness-fastfood-teil-1-ruehrei-broetchen/" title="Fitness-Fastfood – Teil 1: Rührei-Brötchen"><img alt="Rührei-Brötchen" class="attachment-cp-thumb-small size-cp-thumb-small wp-post-image" height="67" loading="lazy" sizes="(max-width: 120px) 100vw, 120px" src="https://www.uebungen.ws/wp-content/uploads/2015/04/ruehrei-broetchen2-120x67.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2015/04/ruehrei-broetchen2-120x67.jpg 120w, https://www.uebungen.ws/wp-content/uploads/2015/04/ruehrei-broetchen2-100x56.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2015/04/ruehrei-broetchen2-300x169.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2015/04/ruehrei-broetchen2.jpg 777w, https://www.uebungen.ws/wp-content/uploads/2015/04/ruehrei-broetchen2-180x101.jpg 180w, https://www.uebungen.ws/wp-content/uploads/2015/04/ruehrei-broetchen2-260x146.jpg 260w, https://www.uebungen.ws/wp-content/uploads/2015/04/ruehrei-broetchen2-373x210.jpg 373w" width="120"/></a>
# </div>
# <h3 class="cp-title-small"><a href="https://www.uebungen.ws/fitness-fastfood-teil-1-ruehrei-broetchen/" rel="bookmark" title="Fitness-Fastfood – Teil 1: Rührei-Brötchen">Fitness-Fastfood – Teil 1: Rührei-Brötchen</a></h3>
# </article>
# <hr class="mh-separator"/> <article class="cp-wrap cp-small clearfix">
# <div class="cp-thumb-small">
# <a href="https://www.uebungen.ws/fruehstueck-2-0-teil-2-der-muesli-shake-hybrid/" title="Frühstück 2.0, Teil 2: Der Müsli-Shake-Hybrid"><img alt="Müsli-Shake-Hybrid" class="attachment-cp-thumb-small size-cp-thumb-small wp-post-image" height="67" loading="lazy" sizes="(max-width: 120px) 100vw, 120px" src="https://www.uebungen.ws/wp-content/uploads/2015/04/muesli-shake-hybrid2-120x67.jpg" srcset="https://www.uebungen.ws/wp-content/uploads/2015/04/muesli-shake-hybrid2-120x67.jpg 120w, https://www.uebungen.ws/wp-content/uploads/2015/04/muesli-shake-hybrid2-100x57.jpg 100w, https://www.uebungen.ws/wp-content/uploads/2015/04/muesli-shake-hybrid2-300x170.jpg 300w, https://www.uebungen.ws/wp-content/uploads/2015/04/muesli-shake-hybrid2.jpg 770w, https://www.uebungen.ws/wp-content/uploads/2015/04/muesli-shake-hybrid2-180x101.jpg 180w, https://www.uebungen.ws/wp-content/uploads/2015/04/muesli-shake-hybrid2-260x146.jpg 260w, https://www.uebungen.ws/wp-content/uploads/2015/04/muesli-shake-hybrid2-373x210.jpg 373w" width="120"/></a>
# </div>
# <h3 class="cp-title-small"><a href="https://www.uebungen.ws/fruehstueck-2-0-teil-2-der-muesli-shake-hybrid/" rel="bookmark" title="Frühstück 2.0, Teil 2: Der Müsli-Shake-Hybrid">Frühstück 2.0, Teil 2: Der Müsli-Shake-Hybrid</a></h3>
# </article>
# <hr class="mh-separator"/> </div></div><div class="sb-widget clearfix"><h4 class="widget-title"><span>Übungen – Top 10</span></h4><div class="menu-10-beliebte-uebungen-container"><ul class="menu" id="menu-10-beliebte-uebungen"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4997" id="menu-item-4997"><a href="https://www.uebungen.ws/bankdruecken/">Bankdrücken</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4998" id="menu-item-4998"><a href="https://www.uebungen.ws/kniebeugen/">Kniebeugen</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4999" id="menu-item-4999"><a href="https://www.uebungen.ws/kreuzheben/">Kreuzheben</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-5000" id="menu-item-5000"><a href="https://www.uebungen.ws/liegestuetze/">Liegestütze</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-5002" id="menu-item-5002"><a href="https://www.uebungen.ws/criss-cross-kaefer/">Criss-Cross / Käfer</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-5003" id="menu-item-5003"><a href="https://www.uebungen.ws/crunches/">Crunches</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-5004" id="menu-item-5004"><a href="https://www.uebungen.ws/klimmzuege/">Klimmzüge</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-5005" id="menu-item-5005"><a href="https://www.uebungen.ws/langhantel-curls/">Langhantel-Curls</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-5006" id="menu-item-5006"><a href="https://www.uebungen.ws/beinpresse/">Beinpresse</a></li>
# </ul></div></div><div class="sb-widget clearfix"><h4 class="widget-title"><span>Neu auf Uebungen.ws</span></h4> <ul class="mh-rp-widget widget-list"> <li class="rp-widget-item"><a href="https://www.uebungen.ws/1rm-rechner-ermittle-dein-one-repetition-maximum/" rel="bookmark" title="1RM Rechner: Ermittle dein One Repetition Maximum">1RM Rechner: Ermittle dein One Repetition Maximum</a></li> <li class="rp-widget-item"><a href="https://www.uebungen.ws/5x5-trainingsplan/" rel="bookmark" title="5×5 Trainingsplan">5×5 Trainingsplan</a></li> <li class="rp-widget-item"><a href="https://www.uebungen.ws/grunduebungen-trainingsplan/" rel="bookmark" title="Grundübungen-Trainingsplan">Grundübungen-Trainingsplan</a></li> <li class="rp-widget-item"><a href="https://www.uebungen.ws/guenstiges-homegym/" rel="bookmark" title="Günstiges Homegym: Zuhause effektiv Muskeln aufbauen">Günstiges Homegym: Zuhause effektiv Muskeln aufbauen</a></li> <li class="rp-widget-item"><a href="https://www.uebungen.ws/trainingsplan-zuhause-mit-kurzhanteln-trainieren/" rel="bookmark" title="Trainingsplan: Zuhause mit Kurzhanteln trainieren">Trainingsplan: Zuhause mit Kurzhanteln trainieren</a></li> </ul></div><div class="sb-widget clearfix"><h4 class="widget-title"><span>Neueste Kommentare</span></h4> <ul class="user-widget widget-list row clearfix"> <li class="uw-wrap clearfix">
# <div class="uw-avatar"><a href="https://www.uebungen.ws/kreuzheben/#comment-59891" title="Alex"><img alt="" class="avatar avatar-64 photo" height="64" loading="lazy" src="https://secure.gravatar.com/avatar/72861285afec653581dda888870aac94?s=64&amp;d=mm&amp;r=g" srcset="https://secure.gravatar.com/avatar/72861285afec653581dda888870aac94?s=128&amp;d=mm&amp;r=g 2x" width="64"/></a></div>
# <div class="uw-text">Alex on <a href="https://www.uebungen.ws/kreuzheben/#comment-59891" title="Alex | Kreuzheben">Kreuzheben</a></div>
# </li> <li class="uw-wrap clearfix">
# <div class="uw-avatar"><a href="https://www.uebungen.ws/liegestuetze/#comment-59831" title="Eva"><img alt="" class="avatar avatar-64 photo" height="64" loading="lazy" src="https://secure.gravatar.com/avatar/32495b9a3aa243f6911d29acd5a6174e?s=64&amp;d=mm&amp;r=g" srcset="https://secure.gravatar.com/avatar/32495b9a3aa243f6911d29acd5a6174e?s=128&amp;d=mm&amp;r=g 2x" width="64"/></a></div>
# <div class="uw-text">Eva on <a href="https://www.uebungen.ws/liegestuetze/#comment-59831" title="Eva | Liegestütze">Liegestütze</a></div>
# </li> <li class="uw-wrap clearfix">
# <div class="uw-avatar"><a href="https://www.uebungen.ws/krafttraining-aufwaermen/#comment-59722" title="Henrik"><img alt="" class="avatar avatar-64 photo" height="64" loading="lazy" src="https://secure.gravatar.com/avatar/a3c18d0f33aa85fe3540469974c22906?s=64&amp;d=mm&amp;r=g" srcset="https://secure.gravatar.com/avatar/a3c18d0f33aa85fe3540469974c22906?s=128&amp;d=mm&amp;r=g 2x" width="64"/></a></div>
# <div class="uw-text">Henrik on <a href="https://www.uebungen.ws/krafttraining-aufwaermen/#comment-59722" title="Henrik | Krafttraining: Aufwärmen nicht vergessen!">Krafttraining: Aufwärmen nicht vergessen!</a></div>
# </li> <li class="uw-wrap clearfix">
# <div class="uw-avatar"><a href="https://www.uebungen.ws/fliegende/#comment-59255" title="JeanZ7"><img alt="" class="avatar avatar-64 photo" height="64" loading="lazy" src="https://secure.gravatar.com/avatar/932cb7644377dc6cd6b6a7da553cdfaa?s=64&amp;d=mm&amp;r=g" srcset="https://secure.gravatar.com/avatar/932cb7644377dc6cd6b6a7da553cdfaa?s=128&amp;d=mm&amp;r=g 2x" width="64"/></a></div>
# <div class="uw-text">JeanZ7 on <a href="https://www.uebungen.ws/fliegende/#comment-59255" title="JeanZ7 | Fliegende">Fliegende</a></div>
# </li> <li class="uw-wrap clearfix">
# <div class="uw-avatar"><a href="https://www.uebungen.ws/trizeps-liegestuetze/#comment-59136" title="Christian"><img alt="" class="avatar avatar-64 photo" height="64" loading="lazy" src="https://secure.gravatar.com/avatar/c095cdbc794e8aa997dd0853a7cff794?s=64&amp;d=mm&amp;r=g" srcset="https://secure.gravatar.com/avatar/c095cdbc794e8aa997dd0853a7cff794?s=128&amp;d=mm&amp;r=g 2x" width="64"/></a></div>
# <div class="uw-text">Christian on <a href="https://www.uebungen.ws/trizeps-liegestuetze/#comment-59136" title="Christian | Trizeps-Liegestütze">Trizeps-Liegestütze</a></div>
# </li> </ul></div></aside>
# </div>
# </div>
# <footer class="mh-footer">
# <div class="wrapper-inner clearfix">
# </div>
# <div class="footer-bottom">
# <div class="wrapper-inner clearfix">
# <div class="copyright-wrap">
# <p class="copyright">© Uebungen.ws (<a href="https://www.uebungen.ws/impressum/">Impressum</a>)</p>
# </div>
# </div>
# </div>
# </footer>
# <script id="wp-embed-js" src="https://www.uebungen.ws/wp-includes/js/wp-embed.min.js?ver=5.8.2" type="text/javascript"></script>
# </body>
# </html>

# %%
category_description = soup.find(id="kategorienbeschreibung")
print(category_description)
# Out:
# <div id="kategorienbeschreibung"><p>Die Schultermuskulatur umgibt das Schultergelenk. Im Bodybuilding wird üblicherweise zwischen drei Teilen der Schulter unterschieden: die <a href="https://www.uebungen.ws/schultern/vordere-schulter/">vordere Schulter</a>, die <a href="https://www.uebungen.ws/schultern/seitliche-schulter/">seitliche Schulter</a> und die <a href="https://www.uebungen.ws/schultern/hintere-schulter/">hintere Schulter</a>. Die Schultermuskulatur bewegt und stabilisiert die Schultern nicht nur in eine, sondern in alle Richtungen. Wer seine Schulter optimal trainieren möchte, der sollte Übungen für alle drei Teile der Schulter in seinen Trainingsplan aufnehmen. Die meisten Grundübungen für den Oberkörper trainieren zumindest einen Teil der Schulter; doch gerade die seitliche Schulter kann auch durch Isolationsübungen trainiert werden.</p>
# </div>

# %%
for item in soup.find_all(class_= "unterkategorie"):
    for item2 in item.find_all("article", class_="content-list"):
        title = item2.find("h3", class_="content-list-title")
        print(title.text)
# Out:
# Reverse Flys
# Butterfly Reverse
# Rudern in Rückenlage
# Reverse Flys am Kabelzug
# Vorgebeugte Reverse Flys am Kabelzug
# Kurzhantel-Schulterdrücken
# Seitheben
# Schulterdrücken
# Aufrechtes Rudern
# Seitheben am Kabelzug
# Kurzhantel-Schulterdrücken
# Frontheben
# Schulterdrücken
# Military Press
# Frontheben mit dem Theraband
